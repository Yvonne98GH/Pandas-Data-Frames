# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    'Population': [35.467, 63.951, 80.94 , 60.665, 127.061, 64.511, 318.523],
    'GDP': [
        1785387,
        2833687,
        3874437,
        2167744,
        4602367,
        2950039,
        17348075
    ],
    'Surface Area': [
        9984670,
        640679,
        357114,
        301336,
        377930,
        242495,
        9525067
    ],
    'HDI': [
        0.913,
        0.888,
        0.916,
        0.873,
        0.891,
        0.907,
        0.915
    ],'Continent': [
        'America',
        'Europe',
        'Europe',
        'Europe',
        'Asia',
        'Europe',
        'America'
    ]
}, columns=['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'])

# %%
df
# Out:
#    Population       GDP  Surface Area    HDI Continent
# 0      35.467   1785387       9984670  0.913   America
# 1      63.951   2833687        640679  0.888    Europe
# 2      80.940   3874437        357114  0.916    Europe
# 3      60.665   2167744        301336  0.873    Europe
# 4     127.061   4602367        377930  0.891      Asia
# 5      64.511   2950039        242495  0.907    Europe
# 6     318.523  17348075       9525067  0.915   America

# %%
df.index = ["Canada","France","Germany","Italy","Japan","United Kingdom","United States"]

# %%
df.columns
# Out:
# Index(['Population', 'GDP', 'Surface Area', 'HDI', 'Continent'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, Canada to United States
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Population    7 non-null      float64
#  1   GDP           7 non-null      int64
#  2   Surface Area  7 non-null      int64
#  3   HDI           7 non-null      float64
#  4   Continent     7 non-null      object
# dtypes: float64(2), int64(2), object(1)
# memory usage: 336.0+ bytes

# %%
df.shape
# Out:
# (7, 5)

# %%
df.describe()
# Out:
#        Population           GDP  Surface Area       HDI
# count    7.000000  7.000000e+00  7.000000e+00  7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429
# std     97.249970  5.494020e+06  4.576187e+06  0.016592
# min     35.467000  1.785387e+06  2.424950e+05  0.873000
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000
# max    318.523000  1.734808e+07  9.984670e+06  0.916000

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America>

# %%
df.size
# Out:
# 35

# %%
df.dtypes
# Out:
# Population      float64
# GDP               int64
# Surface Area      int64
# HDI             float64
# Continent        object
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# float64    2
# int64      2
# object     1
# Name: count, dtype: int64

# %%
df['Population']
# Out:
# Canada             35.467
# France             63.951
# Germany            80.940
# Italy              60.665
# Japan             127.061
# United Kingdom     64.511
# United States     318.523
# Name: Population, dtype: float64

# %%
df.loc["Canada"]
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.iloc[-1]
# Out:
# Population       318.523
# GDP             17348075
# Surface Area     9525067
# HDI                0.915
# Continent        America
# Name: United States, dtype: object

# %%
df["France": "Italy"]
# Out:
#          Population      GDP  Surface Area    HDI Continent
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe
# Italy        60.665  2167744        301336  0.873    Europe

# %%
df.loc["France": "Italy", "Population"]
# Out:
# France     63.951
# Germany    80.940
# Italy      60.665
# Name: Population, dtype: float64

# %%
df.loc["France": "Italy", ["Population","GDP"]]
# Out:
#          Population      GDP
# France       63.951  2833687
# Germany      80.940  3874437
# Italy        60.665  2167744

# %%
df.iloc[0]
# Out:
# Population       35.467
# GDP             1785387
# Surface Area    9984670
# HDI               0.913
# Continent       America
# Name: Canada, dtype: object

# %%
df.iloc[1]
# Out:
# Population       63.951
# GDP             2833687
# Surface Area     640679
# HDI               0.888
# Continent        Europe
# Name: France, dtype: object

# %%
df.iloc[-1]
# Out:
# Population       318.523
# GDP             17348075
# Surface Area     9525067
# HDI                0.915
# Continent        America
# Name: United States, dtype: object

# %%
df.iloc[[0,1,-1]]
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Canada             35.467   1785387       9984670  0.913   America
# France             63.951   2833687        640679  0.888    Europe
# United States     318.523  17348075       9525067  0.915   America

# %%
df.iloc[0:3]
# Out:
#          Population      GDP  Surface Area    HDI Continent
# Canada       35.467  1785387       9984670  0.913   America
# France       63.951  2833687        640679  0.888    Europe
# Germany      80.940  3874437        357114  0.916    Europe

# %%
df.iloc[1:3,3]
# Out:
# France     0.888
# Germany    0.916
# Name: HDI, dtype: float64

# %%
df.iloc[1:3,[0,3]]
# Out:
#          Population    HDI
# France       63.951  0.888
# Germany      80.940  0.916

# %%
df.iloc[1:3,1:3]
# Out:
#              GDP  Surface Area
# France   2833687        640679
# Germany  3874437        357114

# %%
df[df["Population"] >70]
# Out:
#                Population       GDP  Surface Area    HDI Continent
# Germany            80.940   3874437        357114  0.916    Europe
# Japan             127.061   4602367        377930  0.891      Asia
# United States     318.523  17348075       9525067  0.915   America

# %%
df.loc[df["Population"] >70,["Population","GDP"]]
# Out:
#                Population       GDP
# Germany            80.940   3874437
# Japan             127.061   4602367
# United States     318.523  17348075

# %%
df.drop("Canada")
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.drop(["Canada","Japan"])
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.drop(columns = ["Population","HDI"])
# Out:
#                      GDP  Surface Area Continent
# Canada           1785387       9984670   America
# France           2833687        640679    Europe
# Germany          3874437        357114    Europe
# Italy            2167744        301336    Europe
# Japan            4602367        377930      Asia
# United Kingdom   2950039        242495    Europe
# United States   17348075       9525067   America

# %%
df.drop(["Italy","Canada"], axis = 0)
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.drop(["Population","HDI"], axis = 1)
# Out:
#                      GDP  Surface Area Continent
# Canada           1785387       9984670   America
# France           2833687        640679    Europe
# Germany          3874437        357114    Europe
# Italy            2167744        301336    Europe
# Japan            4602367        377930      Asia
# United Kingdom   2950039        242495    Europe
# United States   17348075       9525067   America

# %%
df.drop(["Population","HDI"], axis = "columns")
# Out:
#                      GDP  Surface Area Continent
# Canada           1785387       9984670   America
# France           2833687        640679    Europe
# Germany          3874437        357114    Europe
# Italy            2167744        301336    Europe
# Japan            4602367        377930      Asia
# United Kingdom   2950039        242495    Europe
# United States   17348075       9525067   America

# %%
df.drop(["Canada","Germany"], axis = "rows")
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# France              63.951   2833687        640679  0.888    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df.drop(["Canada","Germany"])
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# France              63.951   2833687        640679  0.888    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
df[["Population","GDP"]]
# Out:
#                 Population       GDP
# Canada              35.467   1785387
# France              63.951   2833687
# Germany             80.940   3874437
# Italy               60.665   2167744
# Japan              127.061   4602367
# United Kingdom      64.511   2950039
# United States      318.523  17348075

# %%
df[["Population","GDP"]] / 100
# Out:
#                 Population        GDP
# Canada             0.35467   17853.87
# France             0.63951   28336.87
# Germany            0.80940   38744.37
# Italy              0.60665   21677.44
# Japan              1.27061   46023.67
# United Kingdom     0.64511   29500.39
# United States      3.18523  173480.75

# %%
crisis = pd.Series([-1_000_000, -0.3], index = ["GDP","HDI"])
crisis
# Out:
# GDP   -1000000.0
# HDI         -0.3
# dtype: float64

# %%
df[["GDP","HDI"]] + crisis
# Out:
#                        GDP    HDI
# Canada            785387.0  0.613
# France           1833687.0  0.588
# Germany          2874437.0  0.616
# Italy            1167744.0  0.573
# Japan            3602367.0  0.591
# United Kingdom   1950039.0  0.607
# United States   16348075.0  0.615

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent
# Canada              35.467   1785387       9984670  0.913   America
# France              63.951   2833687        640679  0.888    Europe
# Germany             80.940   3874437        357114  0.916    Europe
# Italy               60.665   2167744        301336  0.873    Europe
# Japan              127.061   4602367        377930  0.891      Asia
# United Kingdom      64.511   2950039        242495  0.907    Europe
# United States      318.523  17348075       9525067  0.915   America

# %%
35_467_000 - 1_000_000
# Out:
# 34467000

# %%
39 * 5
# Out:
# 195

# %%
195 * 150
# Out:
# 29250

# %%
langs = pd.Series(
    ["French","German","Italian"],
    index = ["France","Germany","Italy"],
    name = "Language"
)

# %%
langs
# Out:
# France      French
# Germany     German
# Italy      Italian
# Name: Language, dtype: object

# %%
df["language"] = langs
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent language
# Canada              35.467   1785387       9984670  0.913   America      NaN
# France              63.951   2833687        640679  0.888    Europe   French
# Germany             80.940   3874437        357114  0.916    Europe   German
# Italy               60.665   2167744        301336  0.873    Europe  Italian
# Japan              127.061   4602367        377930  0.891      Asia      NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe      NaN
# United States      318.523  17348075       9525067  0.915   America      NaN

# %%
df["Language"] = "English"
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent language  \
# Canada              35.467   1785387       9984670  0.913   America      NaN
# France              63.951   2833687        640679  0.888    Europe   French
# Germany             80.940   3874437        357114  0.916    Europe   German
# Italy               60.665   2167744        301336  0.873    Europe  Italian
# Japan              127.061   4602367        377930  0.891      Asia      NaN
# United Kingdom      64.511   2950039        242495  0.907    Europe      NaN
# United States      318.523  17348075       9525067  0.915   America      NaN
#
#                Language
# Canada          English
# France          English
# Germany         English
# Italy           English
# Japan           English
# United Kingdom  English
# United States   English

# %%
df.rename(columns =
         {"HDI":"Human Development Index",
         "Annual Popcorn Consumption":'API'},
          index = {"United Kingdom":"UK","United States":"USA","Argentina":"AR"
          }
         )
# Out:
#          Population       GDP  Surface Area  Human Development Index  \
# Canada       35.467   1785387       9984670                    0.913
# France       63.951   2833687        640679                    0.888
# Germany      80.940   3874437        357114                    0.916
# Italy        60.665   2167744        301336                    0.873
# Japan       127.061   4602367        377930                    0.891
# UK           64.511   2950039        242495                    0.907
# USA         318.523  17348075       9525067                    0.915
#
#         Continent language Language
# Canada    America      NaN  English
# France     Europe   French  English
# Germany    Europe   German  English
# Italy      Europe  Italian  English
# Japan        Asia      NaN  English
# UK         Europe      NaN  English
# USA       America      NaN  English

# %%
df.drop(columns = "language", inplace = True)

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent Language
# Canada              35.467   1785387       9984670  0.913   America  English
# France              63.951   2833687        640679  0.888    Europe  English
# Germany             80.940   3874437        357114  0.916    Europe  English
# Italy               60.665   2167744        301336  0.873    Europe  English
# Japan              127.061   4602367        377930  0.891      Asia  English
# United Kingdom      64.511   2950039        242495  0.907    Europe  English
# United States      318.523  17348075       9525067  0.915   America  English

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
df.reset_index()
# Out:
#             index  Population       GDP  Surface Area    HDI Continent  \
# 0          Canada      35.467   1785387       9984670  0.913   America
# 1          France      63.951   2833687        640679  0.888    Europe
# 2         Germany      80.940   3874437        357114  0.916    Europe
# 3           Italy      60.665   2167744        301336  0.873    Europe
# 4           Japan     127.061   4602367        377930  0.891      Asia
# 5  United Kingdom      64.511   2950039        242495  0.907    Europe
# 6   United States     318.523  17348075       9525067  0.915   America
#
#   Language
# 0  English
# 1  English
# 2  English
# 3  English
# 4  English
# 5  English
# 6  English

# %%
df.set_index("Population")
# Out:
#                  GDP  Surface Area    HDI Continent Language
# Population
# 35.467       1785387       9984670  0.913   America  English
# 63.951       2833687        640679  0.888    Europe  English
# 80.940       3874437        357114  0.916    Europe  English
# 60.665       2167744        301336  0.873    Europe  English
# 127.061      4602367        377930  0.891      Asia  English
# 64.511       2950039        242495  0.907    Europe  English
# 318.523     17348075       9525067  0.915   America  English

# %%
df[["Population","GDP"]]
# Out:
#                 Population       GDP
# Canada              35.467   1785387
# France              63.951   2833687
# Germany             80.940   3874437
# Italy               60.665   2167744
# Japan              127.061   4602367
# United Kingdom      64.511   2950039
# United States      318.523  17348075

# %%
df["GDP"] / df["Population"]
# Out:
# Canada            50339.385908
# France            44310.284437
# Germany           47868.013343
# Italy             35733.025633
# Japan             36221.712406
# United Kingdom    45729.239975
# United States     54464.120330
# dtype: float64

# %%
df["GDP Per Capita"] = df["GDP"] / df["Population"]
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent Language  \
# Canada              35.467   1785387       9984670  0.913   America  English
# France              63.951   2833687        640679  0.888    Europe  English
# Germany             80.940   3874437        357114  0.916    Europe  English
# Italy               60.665   2167744        301336  0.873    Europe  English
# Japan              127.061   4602367        377930  0.891      Asia  English
# United Kingdom      64.511   2950039        242495  0.907    Europe  English
# United States      318.523  17348075       9525067  0.915   America  English
#
#                 GDP Per Capita
# Canada            50339.385908
# France            44310.284437
# Germany           47868.013343
# Italy             35733.025633
# Japan             36221.712406
# United Kingdom    45729.239975
# United States     54464.120330

# %%
df
# Out:
#                 Population       GDP  Surface Area    HDI Continent Language  \
# Canada              35.467   1785387       9984670  0.913   America  English
# France              63.951   2833687        640679  0.888    Europe  English
# Germany             80.940   3874437        357114  0.916    Europe  English
# Italy               60.665   2167744        301336  0.873    Europe  English
# Japan              127.061   4602367        377930  0.891      Asia  English
# United Kingdom      64.511   2950039        242495  0.907    Europe  English
# United States      318.523  17348075       9525067  0.915   America  English
#
#                 GDP Per Capita
# Canada            50339.385908
# France            44310.284437
# Germany           47868.013343
# Italy             35733.025633
# Japan             36221.712406
# United Kingdom    45729.239975
# United States     54464.120330

# %%
df.head
# Out:
# <bound method NDFrame.head of                 Population       GDP  Surface Area    HDI Continent Language  \
# Canada              35.467   1785387       9984670  0.913   America  English
# France              63.951   2833687        640679  0.888    Europe  English
# Germany             80.940   3874437        357114  0.916    Europe  English
# Italy               60.665   2167744        301336  0.873    Europe  English
# Japan              127.061   4602367        377930  0.891      Asia  English
# United Kingdom      64.511   2950039        242495  0.907    Europe  English
# United States      318.523  17348075       9525067  0.915   America  English
#
#                 GDP Per Capita
# Canada            50339.385908
# France            44310.284437
# Germany           47868.013343
# Italy             35733.025633
# Japan             36221.712406
# United Kingdom    45729.239975
# United States     54464.120330  >

# %%
df.head()
# Out:
#          Population      GDP  Surface Area    HDI Continent Language  \
# Canada       35.467  1785387       9984670  0.913   America  English
# France       63.951  2833687        640679  0.888    Europe  English
# Germany      80.940  3874437        357114  0.916    Europe  English
# Italy        60.665  2167744        301336  0.873    Europe  English
# Japan       127.061  4602367        377930  0.891      Asia  English
#
#          GDP Per Capita
# Canada     50339.385908
# France     44310.284437
# Germany    47868.013343
# Italy      35733.025633
# Japan      36221.712406

# %%
df.describe()
# Out:
#        Population           GDP  Surface Area       HDI  GDP Per Capita
# count    7.000000  7.000000e+00  7.000000e+00  7.000000        7.000000
# mean   107.302571  5.080248e+06  3.061327e+06  0.900429    44952.254576
# std     97.249970  5.494020e+06  4.576187e+06  0.016592     6954.983875
# min     35.467000  1.785387e+06  2.424950e+05  0.873000    35733.025633
# 25%     62.308000  2.500716e+06  3.292250e+05  0.889500    40265.998421
# 50%     64.511000  2.950039e+06  3.779300e+05  0.907000    45729.239975
# 75%    104.000500  4.238402e+06  5.082873e+06  0.914000    49103.699626
# max    318.523000  1.734808e+07  9.984670e+06  0.916000    54464.120330

# %%
Population = df["Population"]

# %%
Population.min(), Population.max()
# Out:
# (35.467, 318.523)

# %%
Population.sum()
# Out:
# 751.118

# %%
Population.sum() / len(Population)
# Out:
# 107.30257142857144

# %%
Population.mean()
# Out:
# 107.30257142857144

# %%
Population.std()
# Out:
# 97.24996987121581

# %%
Population.median()
# Out:
# 64.511

# %%
Population.quantile(.25)
# Out:
# 62.308

# %%
Population.quantile([.2,.4,.6,.8,1])
# Out:
# 0.2     61.3222
# 0.4     64.1750
# 0.6     74.3684
# 0.8    117.8368
# 1.0    318.5230
# Name: Population, dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pd.Series()
# Out:
# Series([], dtype: object)

# %%
#Create an empty pandas DataFrame
pd.Series(data = [None], index = [None])
# Out:
# None    None
# dtype: object

# %%
#Create a marvel_df pandas DataFrame with the given marvel data
marvel_data = pd.DataFrame({
'Name': ['Spider- Man', 'Captain America', 'Wolverine', 'Iron Man', 'Thor', 'Thing', 'Mister Fantastic', 'Hulk', 'Beast',
'Invisible Woman', 'Storm', 'Namor', 'Hawkeye', 'Daredevil', 'Doctor Strange', 'Hank Pym', 'Scarlet Witch', 'Wasp',
'Black Widow', 'Vision'],
'Gender' : ['male', 'male', 'male','male', 'male', 'male', 'male', 'male', 'male','female', 'female','male', 'male',
'male','male', 'male', 'female', 'female', 'female', 'male',],
'First_Appearance' : [1962, 1941,1974, 1963, 1963, 1961, 1961, 1962, 1963, 1961, 1975, 1939, 1964, 1964, 1963,
1962, 1964, 1963, 1964, 1968]},
columns = ["Name","Gender","First_Appearance"])

# %%
marvel_data
# Out:
#                 Name  Gender  First_Appearance
# 0        Spider- Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %%
marvel_data.set_index = ["Name"]
marvel_data
# Out:
#                 Name  Gender  First_Appearance
# 0        Spider- Man    male              1962
# 1    Captain America    male              1941
# 2          Wolverine    male              1974
# 3           Iron Man    male              1963
# 4               Thor    male              1963
# 5              Thing    male              1961
# 6   Mister Fantastic    male              1961
# 7               Hulk    male              1962
# 8              Beast    male              1963
# 9    Invisible Woman  female              1961
# 10             Storm  female              1975
# 11             Namor    male              1939
# 12           Hawkeye    male              1964
# 13         Daredevil    male              1964
# 14    Doctor Strange    male              1963
# 15          Hank Pym    male              1962
# 16     Scarlet Witch  female              1964
# 17              Wasp  female              1963
# 18       Black Widow  female              1964
# ...

# %%
#Add index names to the marvel_df (use the character name as index)
marvel_data.index = marvel_data["Name"]
marvel_data
# Out:
#                               Name  Gender  First_Appearance
# Name
# Spider- Man            Spider- Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# ...

# %%
#Drop the name column as it's now the index
marvel_data.drop("Name", axis = 1)
# Out:
#                   Gender  First_Appearance
# Name
# Spider- Man         male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
#Drop 'Namor' and 'Hank Pym' rows
marvel_data.drop(["Namor","Hank Pym"], axis = 0)
# Out:
#                               Name  Gender  First_Appearance
# Name
# Spider- Man            Spider- Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# Doctor Strange      Doctor Strange    male              1963
# ...

# %%
#Show the first 5 elements on marvel_data
marvel_data.head()
#or marvel_data.iloc[:5,]
# Out:
#                             Name Gender  First_Appearance
# Name
# Spider- Man          Spider- Man   male              1962
# Captain America  Captain America   male              1941
# Wolverine              Wolverine   male              1974
# Iron Man                Iron Man   male              1963
# Thor                        Thor   male              1963

# %%
#Show just the sex of the first 5 elements on marvel_df
marvel_data["Gender"].head()
#or marvel_data.iloc[:5,].Gender.to_frame()
# Out:
# Name
# Spider- Man        male
# Captain America    male
# Wolverine          male
# Iron Man           male
# Thor               male
# Name: Gender, dtype: object

# %%
marvel_data.iloc[:5,]
# Out:
#                             Name Gender  First_Appearance
# Name
# Spider- Man          Spider- Man   male              1962
# Captain America  Captain America   male              1941
# Wolverine              Wolverine   male              1974
# Iron Man                Iron Man   male              1963
# Thor                        Thor   male              1963

# %%
marvel_data.iloc[:5,].Gender.to_frame()
# Out:
#                 Gender
# Name
# Spider- Man       male
# Captain America   male
# Wolverine         male
# Iron Man          male
# Thor              male

# %%
#Show the first_appearance of all middle elements on marvel_data
marvel_data[1:-1].First_Appearance.to_frame()
# Out:
#                   First_Appearance
# Name
# Captain America               1941
# Wolverine                     1974
# Iron Man                      1963
# Thor                          1963
# Thing                         1961
# Mister Fantastic              1961
# Hulk                          1962
# Beast                         1963
# Invisible Woman               1961
# Storm                         1975
# Namor                         1939
# Hawkeye                       1964
# Daredevil                     1964
# Doctor Strange                1963
# Hank Pym                      1962
# Scarlet Witch                 1964
# Wasp                          1963
# Black Widow                   1964

# %%
marvel_data
# Out:
#                               Name  Gender  First_Appearance
# Name
# Spider- Man            Spider- Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# ...

# %%
#Show the first and last elements on marvel_data
marvel_data.iloc[[0,-1]]
# Out:
#                     Name Gender  First_Appearance
# Name
# Spider- Man  Spider- Man   male              1962
# Vision            Vision   male              1968

# %%
#Modify the first_appearance of 'Vision' to year 1964
marvel_data.loc["Vision", "First_Appearance"] = 1964
marvel_data
# Out:
#                               Name  Gender  First_Appearance
# Name
# Spider- Man            Spider- Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# ...

# %%
#Add a new column to marvel_data called 'years_since' with the years since first_appearance
marvel_data["years_since"] = 2024 - marvel_data["First_Appearance"]
marvel_data
# Out:
#                               Name  Gender  First_Appearance  years_since
# Name
# Spider- Man            Spider- Man    male              1962           62
# Captain America    Captain America    male              1941           83
# Wolverine                Wolverine    male              1974           50
# Iron Man                  Iron Man    male              1963           61
# Thor                          Thor    male              1963           61
# Thing                        Thing    male              1961           63
# Mister Fantastic  Mister Fantastic    male              1961           63
# Hulk                          Hulk    male              1962           62
# Beast                        Beast    male              1963           61
# Invisible Woman    Invisible Woman  female              1961           63
# Storm                        Storm  female              1975           49
# Namor                        Namor    male              1939           85
# ...

# %%
2024 - marvel_data["First_Appearance"]
# Out:
# Name
# Spider- Man         62
# Captain America     83
# Wolverine           50
# Iron Man            61
# Thor                61
# Thing               63
# Mister Fantastic    63
# Hulk                62
# Beast               61
# Invisible Woman     63
# Storm               49
# Namor               85
# Hawkeye             60
# Daredevil           60
# Doctor Strange      61
# Hank Pym            62
# Scarlet Witch       60
# Wasp                61
# Black Widow         60
# Vision              60
# Name: First_Appearance, dtype: int64

# %%
#Given the marvel_data pandas DataFrame, make a mask showing the female characters
mask = marvel_data["Gender"] == "Female"
mask
# Out:
# Name
# Spider- Man         False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman     False
# Storm               False
# Namor               False
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Hank Pym            False
# Scarlet Witch       False
# Wasp                False
# Black Widow         False
# Vision              False
# Name: Gender, dtype: bool

# %%
mask = marvel_data["Gender"] == "Female"
marvel_data[mask]
# Out:
# Empty DataFrame
# Columns: [Name, Gender, First_Appearance, years_since]
# Index: []

# %%
#Given the marvel_data pandas DataFrame, get the male characters
marvel_data["Gender"] == "Male"
marvel_data
# Out:
#                               Name  Gender  First_Appearance  years_since
# Name
# Spider- Man            Spider- Man    male              1962           62
# Captain America    Captain America    male              1941           83
# Wolverine                Wolverine    male              1974           50
# Iron Man                  Iron Man    male              1963           61
# Thor                          Thor    male              1963           61
# Thing                        Thing    male              1961           63
# Mister Fantastic  Mister Fantastic    male              1961           63
# Hulk                          Hulk    male              1962           62
# Beast                        Beast    male              1963           61
# Invisible Woman    Invisible Woman  female              1961           63
# Storm                        Storm  female              1975           49
# Namor                        Namor    male              1939           85
# ...

# %%
#Given the marvel_data pandas DataFrame, get the characters with first_appearance after 1970
mask = marvel_data["First_Appearance"] > 1970
marvel_data[mask]
# Out:
#                 Name  Gender  First_Appearance  years_since
# Name
# Wolverine  Wolverine    male              1974           50
# Storm          Storm  female              1975           49

# %%
#Given the marvel_data pandas DataFrame, get the female characters with first_appearance after 1970
mask = (marvel_data["First_Appearance"] > 1970) & (marvel_data["Gender"] == "Female")
marvel_data[mask]
# Out:
# Empty DataFrame
# Columns: [Name, Gender, First_Appearance, years_since]
# Index: []

# %%
#Show basic statistics of marvel_data
marvel_data.describe()
# Out:
#        First_Appearance  years_since
# count         20.000000    20.000000
# mean        1961.650000    62.350000
# std            8.298859     8.298859
# min         1939.000000    49.000000
# 25%         1961.750000    60.000000
# 50%         1963.000000    61.000000
# 75%         1964.000000    62.250000
# max         1975.000000    85.000000

# %%
marvel_data.count()
# Out:
# Name                20
# Gender              20
# First_Appearance    20
# years_since         20
# dtype: int64

# %%
years_since = marvel_data["years_since"]

# %%
years_since.mean()
# Out:
# 62.35

# %%
years_since.std()
# Out:
# 8.298858513770371

# %%
#Given the marvel_data pandas DataFrame, show the mean value of first_appearance
First_Appearance = marvel_data["First_Appearance"]
First_Appearance.mean()
#or marvel_data.First_Appearance.mean()
# Out:
# 1961.65

# %%
marvel_data.First_Appearance.mean()
# Out:
# 1961.65

# %%
#Given the marvel_data pandas DataFrame, show the min value of first_appearance
marvel_data.First_Appearance.min()
# Out:
# 1939

# %%
#Given the marvel_data pandas DataFrame, get the characters with the min value of first_appearance
marvel_data.Name == marvel_data.First_Appearance.min()
marvel_data
# Out:
#                               Name  Gender  First_Appearance  years_since
# Name
# Spider- Man            Spider- Man    male              1962           62
# Captain America    Captain America    male              1941           83
# Wolverine                Wolverine    male              1974           50
# Iron Man                  Iron Man    male              1963           61
# Thor                          Thor    male              1963           61
# Thing                        Thing    male              1961           63
# Mister Fantastic  Mister Fantastic    male              1961           63
# Hulk                          Hulk    male              1962           62
# Beast                        Beast    male              1963           61
# Invisible Woman    Invisible Woman  female              1961           63
# Storm                        Storm  female              1975           49
# Namor                        Namor    male              1939           85
# ...

# %%
marvel_data
# Out:
#                               Name  Gender  First_Appearance  years_since
# Name
# Spider- Man            Spider- Man    male              1962           62
# Captain America    Captain America    male              1941           83
# Wolverine                Wolverine    male              1974           50
# Iron Man                  Iron Man    male              1963           61
# Thor                          Thor    male              1963           61
# Thing                        Thing    male              1961           63
# Mister Fantastic  Mister Fantastic    male              1961           63
# Hulk                          Hulk    male              1962           62
# Beast                        Beast    male              1963           61
# Invisible Woman    Invisible Woman  female              1961           63
# Storm                        Storm  female              1975           49
# Namor                        Namor    male              1939           85
# ...

# %%
mask = marvel_data['First_Appearance'] == marvel_data.First_Appearance.min()
marvel_data[mask]
# Out:
#         Name Gender  First_Appearance  years_since
# Name
# Namor  Namor   male              1939           85

# %%
marvel_data
# Out:
#                               Name  Gender  First_Appearance  years_since
# Name
# Spider- Man            Spider- Man    male              1962           62
# Captain America    Captain America    male              1941           83
# Wolverine                Wolverine    male              1974           50
# Iron Man                  Iron Man    male              1963           61
# Thor                          Thor    male              1963           61
# Thing                        Thing    male              1961           63
# Mister Fantastic  Mister Fantastic    male              1961           63
# Hulk                          Hulk    male              1962           62
# Beast                        Beast    male              1963           61
# Invisible Woman    Invisible Woman  female              1961           63
# Storm                        Storm  female              1975           49
# Namor                        Namor    male              1939           85
# ...

# %%
#Plot the values of first_appearance
marvel_data["First_Appearance"]
# Out:
# Name
# Spider- Man         1962
# Captain America     1941
# Wolverine           1974
# Iron Man            1963
# Thor                1963
# Thing               1961
# Mister Fantastic    1961
# Hulk                1962
# Beast               1963
# Invisible Woman     1961
# Storm               1975
# Namor               1939
# Hawkeye             1964
# Daredevil           1964
# Doctor Strange      1963
# Hank Pym            1962
# Scarlet Witch       1964
# Wasp                1963
# Black Widow         1964
# Vision              1964
# Name: First_Appearance, dtype: int64

# %%
#Plot a histogram (plot.hist) with values of first_appearance
plt.hist(marvel_data.First_Appearance)
# Out:
# (array([ 2.,  0.,  0.,  0.,  0.,  0., 16.,  0.,  0.,  2.]),
#  array([1939. , 1942.6, 1946.2, 1949.8, 1953.4, 1957. , 1960.6, 1964.2,
#         1967.8, 1971.4, 1975. ]),
#  <BarContainer object of 10 artists>)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
